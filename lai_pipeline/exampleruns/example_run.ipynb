# %%
# !bgzip -c example/example-input.vcf > example/example-input.vcf.gz
# !bgzip -c example/example-model_chr1.vcf > example/example-model_chr1.vcf.gz
# !bgzip -c example/example-model_chr2.vcf > example/example-model_chr2.vcf.gz

# %%
import os
os.makedirs("example", exist_ok=True)

with open("example/example-input.vcf", "w") as f:
    f.write("""##fileformat=VCFv4.2
##contig=<ID=chr1,length=249250621>
##contig=<ID=chr2,length=243199373>
#CHROM\tPOS\tID\tREF\tALT\tQUAL\tFILTER\tINFO\tFORMAT\tSample1\tSample2
chr1\t752566\trs3094315\tA\tG\t.\tPASS\t.\tGT\t0|1\t1|1
chr1\t768448\trs2905036\tC\tT\t.\tPASS\t.\tGT\t0|0\t0|1
chr2\t485123\trs1234567\tT\tC\t.\tPASS\t.\tGT\t0|1\t0|0
""")

with open("example/example-model_chr1.vcf", "w") as f:
    f.write("""##fileformat=VCFv4.2
##contig=<ID=1,length=249250621>
#CHROM\tPOS\tID\tREF\tALT\tQUAL\tFILTER\tINFO
1\t752566\trs3094315\tA\tG\t.\tPASS\t.
1\t768448\trs2905036\tC\tT\t.\tPASS\t.
1\t800000\trs9999999\tG\tA\t.\tPASS\t.
""")

with open("example/example-model_chr2.vcf", "w") as f:
    f.write("""##fileformat=VCFv4.2
##contig=<ID=2,length=243199373>
#CHROM\tPOS\tID\tREF\tALT\tQUAL\tFILTER\tINFO
2\t485123\trs1234567\tT\tC\t.\tPASS\t.
2\t500000\trs8888888\tA\tT\t.\tPASS\t.
""")

print("Fitxers creats!")
# Out:
# Fitxers creats!

# %%
# !python cli.py --help
# Out:
# usage: cli.py [-h] --input-vcf INPUT_VCF --workdir WORKDIR
#               --model-vcf-template MODEL_VCF_TEMPLATE
#               [--reference-vcf-template REFERENCE_VCF_TEMPLATE]
#               [--reference-fasta REFERENCE_FASTA]
#               [--genetic-map-template GENETIC_MAP_TEMPLATE]
#               [--impute-engine {beagle,none}] [--beagle-jar BEAGLE_JAR]
#               [--bcftools BCFTOOLS] [--java JAVA] [--threads THREADS]
#               [--qc-strict] [--min-exact-match-pct MIN_EXACT_MATCH_PCT]
#               [--allow-inversions] [--allow-other-mismatch]
#               [--auto-normalize-on-qc-fail] [--no-split-beagle-multiallelics]
#               [--log-level {DEBUG,INFO,WARNING,ERROR}]
#
# LAI harmonization pipeline: harmonizes any input VCF to match the format
# expected by a Local Ancestry Inference model.
#
# options:
#   -h, --help            show this help message and exit
#   --input-vcf INPUT_VCF
# ...

# %%
# !python cli.py --input-vcf fitxer_que_no_existeix.vcf.gz --workdir /tmp/test --model-vcf-template "example/example-model_chr{chrom}.vcf.gz"
# Out:
# 2026-04-02 07:33:27,204 | INFO     | Logging initialized at level=INFO
# 2026-04-02 07:33:27,205 | INFO     | === LAI HARMONIZATION PIPELINE ===
# 2026-04-02 07:33:27,205 | INFO     |   input-vcf:              fitxer_que_no_existeix.vcf.gz
# 2026-04-02 07:33:27,205 | INFO     |   workdir:                /tmp/test
# 2026-04-02 07:33:27,205 | INFO     |   model-vcf-template:     example/example-model_chr{chrom}.vcf.gz
# 2026-04-02 07:33:27,205 | INFO     |   reference-vcf-template: (none)
# 2026-04-02 07:33:27,205 | INFO     |   reference-fasta:        (none)
# 2026-04-02 07:33:27,205 | INFO     |   impute-engine:          beagle
# 2026-04-02 07:33:27,205 | INFO     |   beagle-jar:             (none)
# 2026-04-02 07:33:27,205 | INFO     |   threads:                8
# 2026-04-02 07:33:27,205 | INFO     |   qc-strict:              False
# 2026-04-02 07:33:27,205 | INFO     |   log-level:              INFO
# 2026-04-02 07:33:27,205 | INFO     | ==================================
# ...

# %%
# !python cli.py \
  --input-vcf example/example-input.vcf \
  --workdir /tmp/test \
  --model-vcf-template "example/example-model_chr{chrom}.vcf.gz"
# Out:
# 2026-04-02 07:34:59,748 | INFO     | Logging initialized at level=INFO
# 2026-04-02 07:34:59,748 | INFO     | === LAI HARMONIZATION PIPELINE ===
# 2026-04-02 07:34:59,748 | INFO     |   input-vcf:              example/example-input.vcf
# 2026-04-02 07:34:59,749 | INFO     |   workdir:                /tmp/test
# 2026-04-02 07:34:59,749 | INFO     |   model-vcf-template:     example/example-model_chr{chrom}.vcf.gz
# 2026-04-02 07:34:59,749 | INFO     |   reference-vcf-template: (none)
# 2026-04-02 07:34:59,749 | INFO     |   reference-fasta:        (none)
# 2026-04-02 07:34:59,749 | INFO     |   impute-engine:          beagle
# 2026-04-02 07:34:59,749 | INFO     |   beagle-jar:             (none)
# 2026-04-02 07:34:59,749 | INFO     |   threads:                8
# 2026-04-02 07:34:59,749 | INFO     |   qc-strict:              False
# 2026-04-02 07:34:59,749 | INFO     |   log-level:              INFO
# 2026-04-02 07:34:59,749 | INFO     | ==================================
# ...

# %%
# !python cli.py \
  --input-vcf example/example-input.vcf.gz \
  --workdir /tmp/test \
  --model-vcf-template "example/example-model_chr{chrom}.vcf.gz" \
  --impute-engine none \
  --log-level DEBUG
# Out:
# 2026-04-02 07:36:16,037 | INFO     | Logging initialized at level=DEBUG
# 2026-04-02 07:36:16,038 | INFO     | === LAI HARMONIZATION PIPELINE ===
# 2026-04-02 07:36:16,038 | INFO     |   input-vcf:              example/example-input.vcf.gz
# 2026-04-02 07:36:16,038 | INFO     |   workdir:                /tmp/test
# 2026-04-02 07:36:16,038 | INFO     |   model-vcf-template:     example/example-model_chr{chrom}.vcf.gz
# 2026-04-02 07:36:16,038 | INFO     |   reference-vcf-template: (none)
# 2026-04-02 07:36:16,038 | INFO     |   reference-fasta:        (none)
# 2026-04-02 07:36:16,038 | INFO     |   impute-engine:          none
# 2026-04-02 07:36:16,038 | INFO     |   beagle-jar:             (none)
# 2026-04-02 07:36:16,038 | INFO     |   threads:                8
# 2026-04-02 07:36:16,038 | INFO     |   qc-strict:              False
# 2026-04-02 07:36:16,038 | INFO     |   log-level:              DEBUG
# 2026-04-02 07:36:16,038 | INFO     | ==================================
# ...

# %%
# !python cli.py \
  --input-vcf example/example-input.vcf.gz \
  --workdir /tmp/test \
  --model-vcf-template "example/example-model_chr{chrom}.vcf.gz" \
  --reference-vcf-template "example/example-model_chr{chrom}.vcf.gz" \
  --impute-engine none \
  --log-level DEBUG
# Out:
# 2026-04-02 07:38:43,345 | INFO     | Logging initialized at level=DEBUG
# 2026-04-02 07:38:43,345 | INFO     | === LAI HARMONIZATION PIPELINE ===
# 2026-04-02 07:38:43,345 | INFO     |   input-vcf:              example/example-input.vcf.gz
# 2026-04-02 07:38:43,346 | INFO     |   workdir:                /tmp/test
# 2026-04-02 07:38:43,346 | INFO     |   model-vcf-template:     example/example-model_chr{chrom}.vcf.gz
# 2026-04-02 07:38:43,346 | INFO     |   reference-vcf-template: example/example-model_chr{chrom}.vcf.gz
# 2026-04-02 07:38:43,346 | INFO     |   reference-fasta:        (none)
# 2026-04-02 07:38:43,346 | INFO     |   impute-engine:          none
# 2026-04-02 07:38:43,346 | INFO     |   beagle-jar:             (none)
# 2026-04-02 07:38:43,346 | INFO     |   threads:                8
# 2026-04-02 07:38:43,346 | INFO     |   qc-strict:              False
# 2026-04-02 07:38:43,346 | INFO     |   log-level:              DEBUG
# ...

# %%
# !git clone https://github.com/gerardpuchebonjorn/ioannidis
# %cd ioannidis
# Out:
# Cloning into 'ioannidis'...
# remote: Enumerating objects: 135, done.
# remote: Counting objects: 100% (135/135), done.
# remote: Compressing objects: 100% (100/100), done.
# remote: Total 135 (delta 77), reused 75 (delta 31), pack-reused 0 (from 0)
# Receiving objects: 100% (135/135), 66.85 KiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (77/77), done.
# /content/ioannidis

# %%
# !apt-get install -y bcftools
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libhts3 libhtscodecs2
# Suggested packages:
#   python3-numpy python3-matplotlib texlive-latex-recommended
# The following NEW packages will be installed:
#   bcftools libhts3 libhtscodecs2
# 0 upgraded, 3 newly installed, 0 to remove and 7 not upgraded.
# Need to get 1,140 kB of archives.
# After this operation, 3,448 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhtscodecs2 amd64 1.1.1-3 [53.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libhts3 amd64 1.13+ds-2build1 [390 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 bcftools amd64 1.13-1 [697 kB]
# Fetched 1,140 kB in 1s (1,377 kB/s)
# Selecting previously unselected package libhtscodecs2:amd64.
# (Reading database ... 118194 files and directories currently installed.)
# ...

# %%
# !apt-get install -y tabix
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   tabix
# 0 upgraded, 1 newly installed, 0 to remove and 7 not upgraded.
# Need to get 351 kB of archives.
# After this operation, 1,179 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tabix amd64 1.13+ds-2build1 [351 kB]
# Fetched 351 kB in 1s (316 kB/s)
# Selecting previously unselected package tabix.
# (Reading database ... 118268 files and directories currently installed.)
# Preparing to unpack .../tabix_1.13+ds-2build1_amd64.deb ...
# Unpacking tabix (1.13+ds-2build1) ...
# Setting up tabix (1.13+ds-2build1) ...
# Processing triggers for man-db (2.10.2-1) ...
